# %% [markdown]
# ## Log Helper Functions (not used in example)
#
# These functions are helpful to log the prompt used, or output_style the response so it readable.

# %%
from datetime import datetime
from IPython.display import Markdown, display

def display_md_to_html(markdown_text):
    html = Markdown(markdown_text)
    display(html)

def save_response_to_file(file_text):
    # Generate a filename
    now = datetime.now()
    identifier = "intel_SA"  # Set this to something unique to your prompt
    file_type = "md"
    formatted_date = now.strftime("%Y%m%d_%H%M%S")  # Example: 20231127_153210    
    filename = f"{identifier}_{formatted_date}.{file_type}"

    # Save the file
    try:
        with open(filename, "w") as f:
            f.write(file_text)
    except OSError as e:
        print(f"Error saving file: {e}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

prompt_template = """
# PROMPT
## SYSTEM
```markdown
{system}
```

## USER
```markdown
{user}
```

## OUTPUT STYLE
```markdown
{output_style}
```
"""

# %% [markdown]
# ## **Multiple APIs** - Call multiple AI's by sending a list of model names

# %%
system = f"""
You are a career coach with years of experience helping clients customize resumes based on job descriptions.  You are really good at identifying the key skills and experiences that are listed in a job description and helping your clients highlight those in their resumes.
"""

# %%
resume="""
PROFESSIONAL SUMMARY

Mike is a results-driven Mobile Architect with 20+ years of experience delivering high-quality iOS and Android applications. He is a strong leader with a track record of collaboration in cross-functional and remote teams, empowering individuals to achieve ambitious goals. He has a proven track record of leveraging Agile methodologies and industry best practices to streamline development, reduce technical debt, and ensure code quality. Mike's passion for technology and commitment to continuous improvement make him a valuable asset to any team.


Technical Product Leadership: Architected a media platform that scaled to $1B in annual revenue and a mobile platform that optimized logistics, enabling the movement of 25k vehicles per month nationwide.
Cross-Platform Application Delivery at Scale: Developed the all-new March Madness Live platform, ensuring a seamless experience across 18 client platforms, supporting 20M+ concurrent video streams and engaging over 10M viewers daily. 
Generative AI Innovation: Pioneered research and development of AI-powered travel app prototype, leveraging Python web services and generative AI to deliver personalized itineraries with unique cultural experiences.
Cross-Platform Design Excellence: Partnered with UI/UX to integrate Material Design into existing design system, ensuring a cohesive and visually appealing experience for the customer across the entire product line.
Global Tech Community Impact: Recognized as a Google Developer Expert for simplifying complex topics through engaging content, mentoring startups and students, as well as organizing developer meetups.
Author and Speaker: Demonstrated exceptional communication skills by distilling complex technical concepts into clear, actionable guidance as a published author and as a sought-after speaker at industry conferences.

EXPERIENCE

Able Android | Technical Consultant | Phoenix, AZ | Feb 2015 - Present 
Partner with clients to translate complex business needs into actionable technology solutions, leveraging expertise in design thinking, technical architecture, and project management to mitigate risks, optimize resources, and deliver high-quality results.
Tour Genius (Aug 2023 - present): Research and prototype a user-friendly app that uses AI algorithms to create custom travel itineraries that immerse travelers in local culture with unique experiences.
I have successfully designed and developed user interfaces, architected scalable applications, implemented secure media streaming solutions, and integrated custom BLE hardware for clients such as CNN & Jetblue (through Possible Mobile), ClearToken, Medical Memory, AisleFire, and FutureBrands.

Adobe | Lead Software Engineer | San Jose, CA/Remote | Aug 2022 – June 2023 
Demonstrated agility in transitioning from mobile to web development when I contributed to the successful production launch of the Premiere Express Web video editor supporting 43M Creative Cloud subscribers.
Architected and developed an all new native Android video editing platform. Collaborated with a team of 3 to establish a modular architecture and clear project structure, demonstrating strong organizational skills.
Served as the Agile Lead, facilitating sprints, retrospectives, and daily standups to foster a collaborative and efficient team. Created user stories and Agile artifacts, ensuring a structured and transparent development process resulting in streamlined workflows and a more predictable release cadence.

Carvana | Principal Software Engineer | Phoenix, AZ |  Jan 2022 – May 2022
Led the creation of the "Driver Mobile" platform for the logistics department, designed to streamline 9-car hauler operations and facilitate the movement of 25k vehicles per month across our nationwide network of distribution centers. Aligned product strategy with stakeholders and released a prototype for testing.
Championed the adoption of Kotlin Multiplatform (KMM), proposing a future-proof solution for efficient iOS and Android development.
Crafted a persuasive proposal for the KMM strategy, securing company-wide architectural approval from Director and VP Levels.
Delivered a KMM analytics library, validating the viability and benefits of the proposed architecture.

Turner Sports | Architect - March Madness Live Platform | Atlanta, GA/Remote | Jan 2020 – Apr 2021
Architected an all-new March Madness Live streaming platform, ensuring a seamless experience across 18 client platforms and 20M+ concurrent video streams, and over 10M viewers in a single day. This is the official media platform for the tournament and the NCAA which brings in approximately $1B annually in revenue.
Collaborated with stakeholders to author architectural specifications, demonstrating a comprehensive platform vision. This provided direction and clarity across the project.
Wrote the specification and oversaw the successful, on-time, and to-spec delivery of the following functional components: Design, Display Ads, Monitoring, Settings, and Telemetry (Analytics).
Led a 10-person Android team, delivering a cutting-edge app aligned with Modern Android Development (MAD) standards. Created a modular app from scratch, delivering a high-quality and maintainable codebase.
Made core contributions to the Android codebase, directly impacting application quality and functionality. Application surpassed 5M downloads and increased from 3.9 to a 4.6-star rating on the Google Play store.
Partnered with the UI/UX team to create a unified Design System, ensuring a consistent and engaging user experience across diverse platforms. Fostered seamless collaboration between developers and designers, resulting in improved efficiency and a cohesive user interface that maintained brand integrity across all platforms.

Previous
Nerdery | Principal Software Engineer | Bloomington, MN, Remote | Aug 2017 - Dec 2019
Epocrates/athenahealth | Lead Mobile Engineer | San Mateo, CA, Remote | 1/2013 - 2/2015
Choice Hotels International | Senior Software Engineer | Phoenix, AZ | 1/2008 - 2/2012
Lockheed Martin Space Systems | Programmer\Analyst | AZ and CO | 12/1997 - 6/2007 

PERSONAL ACHIEVEMENTS

Google Developer Expert Android | May 2014 - present				                   
I was recognized by Google as one of the 1st GDEs in the US for having exemplary expertise in software and technology. I have established strong relationships in this global network of experienced and esteemed developer professionals.
Articles, podcasts, and video content have reached millions of developers worldwide. 
Mentored corporate partners, startup founders (via Startup Launchpad) and students (via Google Student Groups) to help them create excellent products that serve the customer in a positive and unique way.
Google Design Sprint Certified | May 2016
Published Author | October 2013
Book: “Android Developer Tools Essentials” O’Reilly Media 
Worldwide Speaker
I have delivered engaging presentations to thousands of developers worldwide at renowned industry conferences, including Google I/O, Oredev, O'Reilly OSCON, Droidcon and numerous DevFest/GDG events.
Volunteer Service
Hustle 2.0, engaged with the organization to advance their mission of reducing recidivism through participation in coaching and mentoring programs for incarcerated individuals, including on-site visits in correctional facilities (March 2020 – Present).


EDUCATION

Master of Science, Computer Information Systems | University of Phoenix | Denver, CO
Masters Project: Designing and Implementing Instruction on the World Wide Web.

Bachelor of Science, Industrial Technology  | Colorado State University | Fort Collins, CO
 Student Senator for College of Applied Human Sciences, and member of Lambda Chi Alpha
"""

# %%
job_description = """
Intel is looking for an AI Software Solutions Engineer to join the AI Community Enablement team. As a member of this team, you would engage with startups and the AI developer community to drive broad education and adoption of Intel AI software and hardware.


In this role, you get to combine AI engineering expertise, broad developer outreach, and direct customer engagement. You would deliver technical training and content through workshops, sample code, conferences, meet-ups, blogs, videos, and other direct outreach (on platforms like Hugging Face, Kaggle, GitHub, Medium, and YouTube). 50 percent of your time initially would be devoted to working directly with startup customers. This position may require up to 10 percent travel to events like in-person team meetings, external workshops, and developer conferences.

Some of the tasks you would be expected to work on in the first year at Intel:

Getting requirements from startups, and architecting and scaling products on Intel hardware
Build and execute pipelines to deploy fine-tuned task-specific generative AI models: large language models (LLMs), computer vision models, latent diffusion models relevant to specific verticals onto Hugging Face and other platforms.
Identify datasets and create synthetic datasets to fine-tune models.
Create and amplify your work through workshops, code samples, blogs, videos, and other content for AI developers and customers, so that others can create alongside you.
Drive alignment with stakeholders across Intel to validate and amplify your work.
The position offers an excellent opportunity to advance your software engineering skills, leadership skills, and developer relationship skills. It provides a unique direct insight into key players in the AI software market.

Behavioral Traits:

Exceptional English written and oral communication.
Self-motivation to drive your own goals, career, and success.

Qualifications

You must possess the below minimum qualifications to be initially considered for this position. Preferred qualifications are in addition to the minimum requirements and are considered a plus factor in identifying top candidates. Experience would be obtained through a combination of prior education level classes, and current level school classes, projects, research, and relevant previous job and/or internship experience.


Minimum Qualifications:

The candidate must possess a Bachelor’s degree (with 3+ years’ work experience) or Master’s degree (with 2+ years’ work experience) in a scientific or engineering discipline.
2+ years’ experience in areas below:

Software development in Python.
Experience committing to open-source projects (eg., GitHub, Hugging Face).
Experience with popular AI frameworks such as PyTorch and Transformers.
Demonstrated project work in deep learning, generative AI, and Large Language Models (LLMs).
Experience working in a Linux environment.
Technical training content with compelling code samples and demos.
Conducted training workshops, webinars, and hackathons.

Preferred Qualifications:

A solid reputation and following in AI developer communities.
Experience with Intel-optimized AI libraries like Intel Extension for PyTorch.
Experience working with startups or accelerator programs for startups.
Experienced in fine-tuning generative AI models.
Deployed local LLMs on client devices (eg., llama.cpp or Ollama).
Proficiency and understanding of Intel data center and client hardware.

Inside this Business Group

Enable amazing computing experiences with Intel Software continues to shape the way people think about computing – across CPU, GPU, and FPGA architectures. Get your hands on new technology and collaborate with some of the smartest people in the business. Our developers and software engineers work in all software layers, across multiple operating systems and platforms to enable cutting-edge solutions. Ready to solve some of the most complex software challenges? Explore an impactful and innovative career in Software.

Posting Statement

All qualified applicants will receive consideration for employment without regard to race, color, religion, religious creed, sex, national origin, ancestry, age, physical or mental disability, medical condition, genetic information, military and veteran status, marital status, pregnancy, gender, gender expression, gender identity, sexual orientation, or any other characteristic protected by local law, regulation, or ordinance.
Benefits

We offer a total compensation package that ranks among the best in the industry. It consists of competitive pay, stock, bonuses, as well as, benefit programs which include health, retirement, and vacation. Find more information about all of our Amazing Benefits here.


Annual Salary Range for jobs which could be performed in US, Colorado, New York, Washington, California: $162,082.00-$243,222.00
*Salary range dependent on a number of factors including location and experience


Working Model

This role is available as a fully home-based and generally would require you to attend Intel sites only occasionally based on business need. This role may also be available as our hybrid work model which allows employees to split their time between working on-site at their assigned Intel site and off-site.
In certain circumstances the work model may change to accommodate business needs.
"""

# %%
user = f"""
take your time to perform the following tasks for the following resume: {resume} and job description: {job_description}:
1. Analyze both documents to determine if the content matches
2. Determine opportunies to use keywords from the job description that will work well on the resume
3. Determine and items on the resume that should be highlighted or mentioned more to make the candidate appear to be a better match.
4. Provide a summary of the analysis
"""

# %%
output_style = "Output the response as a list of modfications to make, and list the exact words to add or remove from the resume"

# %%
import multi_ai_hub as mah

# Possible Models to use:
# ANTHROPIC_OPUS = "claude-3-opus-20240229"
# ANTHROPIC_SONNET = "claude-3-sonnet-20240229"
# GEMINI_PRO = "gemini-pro"
# HUGGINGFACE_BLOOM = "bigscience/bloom"
# HUGGINGFACE_GEMMA7B = "google/gemma-7b"
# OPEN_AI_GPT35TURBO = "gpt-3.5-turbo"
# OPEN_AI_GPT4 = "gpt-4"
# OPEN_AI_GPT4PREVIEW = "gpt-4-0125-preview"
# MISTRAL_7B = "mistral-7b-instruct"
# MIXTRAL_8X7B = "mixtral-8x7b-instruct"
# SONAR_MED_ONLINE = "sonar-medium-online"
models = [  
    mah.ANTHROPIC_OPUS,
    mah.GEMINI_PRO
]

response = mah.generate_text(models, system, user, output_style)

# Output the response to the console
print(response)

# Optionally, use the custom logging functions to display and save the response
# prompt = prompt_template.format(system=system,
#                                 user=user,
#                                 output_style=output_style)
# display_md_to_html(prompt + response)
# save_response_to_file(prompt + response)
# Out:
# # MODEL: claude-3-opus-20240229
# Here are my recommendations for modifying the resume to better match the job description:
#
# Modifications to make:
# 1. Add "AI Software Solutions Engineer" to the Professional Summary to match the job title
# 2. Highlight experience with Python, open-source projects, AI frameworks like PyTorch, and generative AI/LLMs in the Professional Summary
# 3. Add a bullet point under Technical Product Leadership in the Professional Summary about architecting and scaling products on Intel hardware for startups
# 4. Elaborate on the "Generative AI Innovation" bullet point - mention fine-tuning task-specific generative AI models, identifying datasets, and deploying models on platforms like Hugging Face
# 5. Add a bullet point about creating technical training content, code samples, blogs, videos etc. for AI developers under Global Tech Community Impact in the Professional Summary
# ...
